# %%
# %load_ext autoreload
# %autoreload 2

import os
import pickle
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import torch
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from torch.utils.data import DataLoader, Dataset, SubsetRandomSampler
import torch.nn as nn
import torch.nn.functional as F
import math
import json
from tqdm import tqdm
import more_itertools as mit
import copy
import time
import random

random.seed(2)
torch.manual_seed(2)

# %%
import numpy as np
from sklearn import preprocessing
import scipy.io as sio
from sklearn import linear_model
from scipy import interpolate
import csv

# %%
from utils.preprocessing import Data_preprocess , processing
from model.positional_encoding import PositionalEncoding
from model.encoder import EncoderLayer , TransformerEncoder
from model.decoder import DecoderLayer , TransformerDecoder
from model.multihead_attention import MultiHeadSelfAttention
from model.dense_layer import Dense_Layer
from utils.trainer import Trainer

# %%
# check if gpu is available and choose the best device
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
device
# Out:
# 'cpu'

# %% [markdown]
# # All Preprocess Func

# %%
class cmapss_dataset(Dataset):
    def __init__(self, x_data, y_data):
        self.x_data = torch.from_numpy(x_data).to(device).to(torch.float64)  # Convert numpy array to PyTorch tensor
        self.y_data = torch.from_numpy(y_data[0]).to(device).to(torch.float64)
        
    def __getitem__(self, index):
        x = self.x_data[index]
        y = self.y_data[index]
        y = y.reshape((1))
        return x, y
    
    def __len__(self):
        return len(self.x_data)

# %%
seq_len = 60
data = processing ('./cmapssdata/train_FD001.txt', 
                   './cmapssdata/test_FD001.txt', 
                   './cmapssdata/RUL_FD001.txt',
                   seq_len , [2, 3, 4, 5, 9, 10, 14, 20, 22, 23], 125.0, 14)
trainX, trainY, testX, testY = data.get_data()

# %%
train_dataset = cmapss_dataset(trainX,trainY)
test_dataset = cmapss_dataset(testX,testY)

# %%
next(iter(train_dataset))[0].shape ,next(iter(train_dataset))[1].shape
# Out:
# (torch.Size([60, 14]), torch.Size([1]))

# %% [markdown]
# ## To DataLoaders

# %%
def create_data_loaders(train_dataset,test_dataset , batch_size, shuffle=True):
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=shuffle)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    return train_loader , test_loader

# %%
batch_size = 64
train_loader, test_loader = create_data_loaders(
        train_dataset, test_dataset , batch_size
    )

# %%
next(iter(train_loader))[0].shape
# Out:
# torch.Size([64, 60, 14])

# %% [markdown]
# # Model

# %%
class GaussianNoise(nn.Module):
    def __init__(self, noise_ratio=0.3, corruption_ratio=0.35):
        super().__init__()
        self.noise_ratio = noise_ratio
        self.corruption_ratio = corruption_ratio

    def forward(self, x):
        """
        x: (B, T, C)
        """
        if not self.training or self.noise_ratio == 0.0:
            return x, None

        B, T, C = x.shape
        device = x.device

        # sample corruption mask (B, T, 1)
        corruption_mask = (
            torch.rand(B, T, device=device) < self.corruption_ratio
        ).unsqueeze(-1)

        # channel-wise std
        std = x.std(dim=(0, 1), keepdim=True)

        noise = torch.randn_like(x) * std * self.noise_ratio

        # apply noise only on selected positions
        x_noised = torch.where(corruption_mask, x + noise, x)

        return x_noised, corruption_mask

# %% [markdown]
# # Transformer

# %%
class DenoisingJointEmbedding(nn.Module):

    def __init__(
        self,
        n_features,
        window_size,
        enc_seq_len,
        out_dim,
        n_encoder_layers =3,
        n_heads=7,
        ff_hidden = 1024
    ):
        super(DenoisingJointEmbedding, self).__init__()
        
        #transformer design
        d_model = n_features
        self.encoder = TransformerEncoder(n_encoder_layers, n_heads, d_model , ff_hidden, window_size)
        self.encoder_noised = TransformerEncoder(n_encoder_layers, n_heads, d_model , ff_hidden, window_size)
        self.dense_layer_regressor = Dense_Layer(d_model,enc_seq_len)
        self.gaussian_noise = GaussianNoise()
        
    def forward(self, x):
        # x shape (b, n, k): b - batch size, n - window size, k - number of features
        x = x.to(torch.float64)
        x = x[:,:enc_seq_len]
        x_noised = self.gaussian_noise(x)[0]
        # print(f'x_noised : {x_noised}')
        encoder_out = self.encoder(x,x_noised)
        # print(encoder_out.shape)
        # encoder_out_noised = self.encoder_noised(noised_x)
        estimated_rul = self.dense_layer_regressor(encoder_out)
        # return predictions
        return estimated_rul

# %%
#The number of useful sensors (which means the number of features) 
useful_sensors_number = 14
# FD001 best config : head = 7 , n_enc = 3 , n_dec = 2
dim_val = 14 #64
dim_attn = 14 #64
n_heads = 2

n_encoder_layers = 1

max_rul = 125
lr = 0.001 
enc_seq_len = trainX.shape[1]
output_sequence_length = 1

# %%
n_features = trainX.shape[2]
window_size = enc_seq_len
out_dim = n_features
feat_gat_embed_dim = None
time_gat_embed_dim = None
use_gatv2 = True
alpha = 0.2
dropout = 0.1

# %%
model = DenoisingJointEmbedding(
        n_features,
        window_size,
        enc_seq_len,
        out_dim,
        n_encoder_layers = n_encoder_layers,
        n_heads=n_heads
    )

# %%
model
# Out:
# DenoisingJointEmbedding(
#   (encoder): TransformerEncoder(
#     (pos_encoding): PositionalEncoding()
#     (encoder_layers): ModuleList(
#       (0): EncoderLayer(
#         (self_attn): MultiHeadSelfAttention(
#           (linear_q): Linear(in_features=14, out_features=14, bias=True)
#           (linear_k): Linear(in_features=14, out_features=14, bias=True)
#           (linear_v): Linear(in_features=14, out_features=14, bias=True)
#           (linear_out): Linear(in_features=14, out_features=14, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feedforward): Sequential(
#           (0): Linear(in_features=14, out_features=1024, bias=True)
#           (1): ReLU()
#           (2): Dropout(p=0.1, inplace=False)
#           (3): Linear(in_features=1024, out_features=14, bias=True)
#           (4): Dropout(p=0.1, inplace=False)
#         )
#         (norm1): LayerNorm((14,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((14,), eps=1e-05, elementwise_affine=True)
#         (norm1_noised): LayerNorm((14,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (encoder_noised): TransformerEncoder(
#     (pos_encoding): PositionalEncoding()
#     (encoder_layers): ModuleList(
#       (0): EncoderLayer(
#         (self_attn): MultiHeadSelfAttention(
#           (linear_q): Linear(in_features=14, out_features=14, bias=True)
#           (linear_k): Linear(in_features=14, out_features=14, bias=True)
#           (linear_v): Linear(in_features=14, out_features=14, bias=True)
#           (linear_out): Linear(in_features=14, out_features=14, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feedforward): Sequential(
#           (0): Linear(in_features=14, out_features=1024, bias=True)
#           (1): ReLU()
#           (2): Dropout(p=0.1, inplace=False)
#           (3): Linear(in_features=1024, out_features=14, bias=True)
#           (4): Dropout(p=0.1, inplace=False)
#         )
#         (norm1): LayerNorm((14,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((14,), eps=1e-05, elementwise_affine=True)
#         (norm1_noised): LayerNorm((14,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (dense_layer_regressor): Dense_Layer(
#     (fc): Sequential(
#       (0): Linear(in_features=840, out_features=64, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#       (2): ReLU()
#       (3): Linear(in_features=64, out_features=16, bias=True)
#       (4): Dropout(p=0.1, inplace=False)
#       (5): ReLU()
#       (6): Linear(in_features=16, out_features=1, bias=True)
#     )
#   )
#   (gaussian_noise): GaussianNoise()
# )

# %% [markdown]
# # Model To Gpu

# %%
model = model.to(device)
model = model.to(torch.float64)

# %% [markdown]
# ## Training

# %% [markdown]
# #### define RUL Loss function

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()
    def forward(self,yhat,y,mode="train",overestimation_penalty=True):
        # L2 regularization
        l2_lambda = 0.1
        l2_norm = sum(p.pow(2.0).sum()
                      for p in list(model.parameters())[-4:])
        L2_regularization = l2_lambda*l2_norm
        # Asymetric score
        asym_penalty_unit = torch.tensor([0.0])
        #asym_penalty_rate = 0.001
        diff = yhat - y
        #penalty_unit = torch.where(diff >= 0 , diff , 0.0  ).to(device, dtype=torch.float64)
        asym_penalty_unit = torch.where(diff >= 0 , torch.exp(diff/13.0) - 1 , torch.exp(-(diff/10.0)) - 1 ).to(device, dtype=torch.float64)
        if mode == "train" :
            #asym_score_penalty = asym_penalty_unit * asym_penalty_rate
            if overestimation_penalty:
                squared_diff = diff ** 2 
            else :
                squared_diff = diff ** 2 
            rmse = torch.sqrt(torch.mean(squared_diff)) 
            #rmse =  torch.mean(squared_diff) + torch.mean(penalty)
            
            loss = (rmse , torch.sum(asym_penalty_unit) )
        elif mode == "test" :
            rmse = torch.sqrt(self.mse(y,yhat))
            loss = (rmse, torch.sum(asym_penalty_unit))
        return loss

# %%
# def alignment_loss(z_clean, z_noised):
#     # stop-gradient on clean branch (teacher)
#     z_clean = z_clean.detach()
#     z_clean = nn.functional.normalize(z_clean, dim=-1)
#     z_noised = nn.functional.normalize(z_noised, dim=-1)
#     return 1 - (z_clean * z_noised).sum(dim=-1).mean()

# %%
init_lr = 0.001
use_cuda = True

optimizer = torch.optim.Adam(model.parameters(), lr=init_lr)
loss_function = RMSELoss()
epochs = 100

# %%
trainer = Trainer(model, train_loader, test_loader, testY, loss_function, optimizer)

# %%
trainer.start_training_loop(epochs) # enc MHA shape = [1, 60, 42] , dec MHA shape = [1, 60, 42]
# Out:
# epoch  0 :
#  --> train loss ( RMSE ) : 34.5122 , score : 7818.7252
# --> test_loss ( RMSE ) = 25.82056744104193 , score : 2015.8745
# -----> Best loss ( RMSE ) 25.82056744104193
# ------> Execution time: 0.5736825466156006 seconds
# epoch  1 :
#  --> train loss ( RMSE ) : 35.4704 , score : 38990.2069
# --> test_loss ( RMSE ) = 25.913535056740855 , score : 2228.5970
# -----> Best loss ( RMSE ) 25.82056744104193
# ------> Execution time: 0.32755160331726074 seconds
# epoch  2 :
#  --> train loss ( RMSE ) : 29.6931 , score : 5312.1558
# --> test_loss ( RMSE ) = 25.287954703502756 , score : 1342.0420
# -----> Best loss ( RMSE ) 25.287954703502756
# ------> Execution time: 0.327181339263916 seconds
# epoch  3 :
#  --> train loss ( RMSE ) : 28.7768 , score : 2927.6283
# --> test_loss ( RMSE ) = 24.961306640462276 , score : 1559.7722
# -----> Best loss ( RMSE ) 24.961306640462276
# ------> Execution time: 0.3330044746398926 seconds
# epoch  4 :
#  --> train loss ( RMSE ) : 32.5718 , score : 14428.5716
# --> test_loss ( RMSE ) = 25.435425104324146 , score : 2141.8796
# -----> Best loss ( RMSE ) 24.961306640462276
# ------> Execution time: 0.30904316902160645 seconds
# epoch  5 :
#  --> train loss ( RMSE ) : 34.4284 , score : 112237.6049
# --> test_loss ( RMSE ) = 25.599299771037668 , score : 2366.6493
# -----> Best loss ( RMSE ) 24.961306640462276
# ------> Execution time: 0.3217191696166992 seconds
# epoch  6 :
#  --> train loss ( RMSE ) : 34.8764 , score : 54624.6562
# --> test_loss ( RMSE ) = 24.064392830817532 , score : 1297.7977
# -----> Best loss ( RMSE ) 24.064392830817532
# ------> Execution time: 0.5345942974090576 seconds
# epoch  7 :
#  --> train loss ( RMSE ) : 32.9580 , score : 7090.7517
# --> test_loss ( RMSE ) = 24.24197976948605 , score : 1027.8558
# -----> Best loss ( RMSE ) 24.064392830817532
# ------> Execution time: 0.35872602462768555 seconds
# epoch  8 :
#  --> train loss ( RMSE ) : 31.5696 , score : 2989.6653
# --> test_loss ( RMSE ) = 23.420638521425975 , score : 1084.3057
# -----> Best loss ( RMSE ) 23.420638521425975
# ------> Execution time: 0.3772575855255127 seconds
# epoch  9 :
#  --> train loss ( RMSE ) : 31.7060 , score : 7977.3018
# --> test_loss ( RMSE ) = 24.521190893038433 , score : 2188.0122
# -----> Best loss ( RMSE ) 23.420638521425975
# ------> Execution time: 0.36835718154907227 seconds
# epoch  10 :
#  --> train loss ( RMSE ) : 31.4233 , score : 16522.3978
# --> test_loss ( RMSE ) = 25.687376382381483 , score : 2986.4398
# -----> Best loss ( RMSE ) 23.420638521425975
# ------> Execution time: 0.45258212089538574 seconds
# epoch  11 :
#  --> train loss ( RMSE ) : 32.2933 , score : 5596.5719
# --> test_loss ( RMSE ) = 22.3359503517769 , score : 1094.5888
# -----> Best loss ( RMSE ) 22.3359503517769
# ------> Execution time: 0.33658790588378906 seconds
# epoch  12 :
#  --> train loss ( RMSE ) : 34.0065 , score : 9792.9900
# --> test_loss ( RMSE ) = 24.21445725968307 , score : 902.8064
# -----> Best loss ( RMSE ) 22.3359503517769
# ------> Execution time: 0.33362507820129395 seconds
# epoch  13 :
#  --> train loss ( RMSE ) : 29.5354 , score : 1627.1272
# --> test_loss ( RMSE ) = 22.287811954741404 , score : 828.0677
# -----> Best loss ( RMSE ) 22.287811954741404
# ------> Execution time: 0.3091130256652832 seconds
# epoch  14 :
#  --> train loss ( RMSE ) : 27.8896 , score : 4137.4869
# --> test_loss ( RMSE ) = 21.367413014346944 , score : 1060.4821
# -----> Best loss ( RMSE ) 21.367413014346944
# ------> Execution time: 0.5074846744537354 seconds
# epoch  15 :
#  --> train loss ( RMSE ) : 23.4370 , score : 962.2301
# --> test_loss ( RMSE ) = 25.95045979913804 , score : 3526.4337
# -----> Best loss ( RMSE ) 21.367413014346944
# ------> Execution time: 0.6082148551940918 seconds
# epoch  16 :
#  --> train loss ( RMSE ) : 32.7407 , score : 9801.9574
# --> test_loss ( RMSE ) = 24.783938441359595 , score : 2864.2755
# -----> Best loss ( RMSE ) 21.367413014346944
# ------> Execution time: 0.35898280143737793 seconds
# epoch  17 :
#  --> train loss ( RMSE ) : 28.5622 , score : 3075.0137
# --> test_loss ( RMSE ) = 20.452023304607586 , score : 806.3444
# -----> Best loss ( RMSE ) 20.452023304607586
# ------> Execution time: 0.44614458084106445 seconds
# epoch  18 :
#  --> train loss ( RMSE ) : 33.0544 , score : 26167.3891
# --> test_loss ( RMSE ) = 25.763490516734777 , score : 1000.0383
# -----> Best loss ( RMSE ) 20.452023304607586
# ------> Execution time: 0.35018324851989746 seconds
# epoch  19 :
#  --> train loss ( RMSE ) : 35.8792 , score : 2569.6240
# --> test_loss ( RMSE ) = 21.83438646857512 , score : 687.6498
# -----> Best loss ( RMSE ) 20.452023304607586
# ------> Execution time: 0.308544397354126 seconds
# epoch  20 :
#  --> train loss ( RMSE ) : 28.9615 , score : 1922.2857
# --> test_loss ( RMSE ) = 23.03735106117596 , score : 2067.7077
# -----> Best loss ( RMSE ) 20.452023304607586
# ------> Execution time: 0.31679630279541016 seconds
# epoch  21 :
#  --> train loss ( RMSE ) : 36.9341 , score : 47285.7418
# --> test_loss ( RMSE ) = 28.257490689419278 , score : 4847.5074
# -----> Best loss ( RMSE ) 20.452023304607586
# ------> Execution time: 0.45406484603881836 seconds
# epoch  22 :
#  --> train loss ( RMSE ) : 31.6237 , score : 4911.1959
# --> test_loss ( RMSE ) = 23.66519171296727 , score : 2343.3692
# -----> Best loss ( RMSE ) 20.452023304607586
# ------> Execution time: 0.3431055545806885 seconds
# epoch  23 :
#  --> train loss ( RMSE ) : 27.4021 , score : 2564.7299
# --> test_loss ( RMSE ) = 19.086551950876576 , score : 639.5596
# -----> Best loss ( RMSE ) 19.086551950876576
# ------> Execution time: 0.3085336685180664 seconds
# epoch  24 :
#  --> train loss ( RMSE ) : 27.1663 , score : 2002.4058
# --> test_loss ( RMSE ) = 21.884226950336558 , score : 646.2062
# -----> Best loss ( RMSE ) 19.086551950876576
# ------> Execution time: 0.29438138008117676 seconds
# epoch  25 :
#  --> train loss ( RMSE ) : 32.3090 , score : 6258.4024
# --> test_loss ( RMSE ) = 21.121574378145866 , score : 596.4904
# -----> Best loss ( RMSE ) 19.086551950876576
# ------> Execution time: 0.3821876049041748 seconds
# epoch  26 :
#  --> train loss ( RMSE ) : 31.4031 , score : 6887.8787
# --> test_loss ( RMSE ) = 18.84796892886154 , score : 535.6007
# -----> Best loss ( RMSE ) 18.84796892886154
# ------> Execution time: 0.4425954818725586 seconds
# epoch  27 :
#  --> train loss ( RMSE ) : 26.5725 , score : 1449.2369
# --> test_loss ( RMSE ) = 19.004848849861578 , score : 880.4748
# -----> Best loss ( RMSE ) 18.84796892886154
# ------> Execution time: 0.2941751480102539 seconds
# epoch  28 :
#  --> train loss ( RMSE ) : 28.8513 , score : 13220.1288
# --> test_loss ( RMSE ) = 20.945284008536163 , score : 1380.0981
# -----> Best loss ( RMSE ) 18.84796892886154
# ------> Execution time: 0.3222019672393799 seconds
# epoch  29 :
#  --> train loss ( RMSE ) : 31.9825 , score : 43892.1751
# --> test_loss ( RMSE ) = 19.900508405781302 , score : 1111.5821
# -----> Best loss ( RMSE ) 18.84796892886154
# ------> Execution time: 0.2758307456970215 seconds
# epoch  30 :
#  --> train loss ( RMSE ) : 28.4707 , score : 3573.1349
# --> test_loss ( RMSE ) = 17.570119760131742 , score : 512.4720
# -----> Best loss ( RMSE ) 17.570119760131742
# ------> Execution time: 0.44441986083984375 seconds
# epoch  31 :
#  --> train loss ( RMSE ) : 25.4131 , score : 4041.7555
# --> test_loss ( RMSE ) = 18.26384916185908 , score : 447.7302
# -----> Best loss ( RMSE ) 17.570119760131742
# ------> Execution time: 0.3213975429534912 seconds
# epoch  32 :
#  --> train loss ( RMSE ) : 28.4997 , score : 1239.8260
# --> test_loss ( RMSE ) = 17.128984567699252 , score : 477.4464
# -----> Best loss ( RMSE ) 17.128984567699252
# ------> Execution time: 0.3089179992675781 seconds
# epoch  33 :
#  --> train loss ( RMSE ) : 22.7549 , score : 723.5633
# --> test_loss ( RMSE ) = 19.386935777856525 , score : 1061.4276
# -----> Best loss ( RMSE ) 17.128984567699252
# ------> Execution time: 0.35487890243530273 seconds
# epoch  34 :
#  --> train loss ( RMSE ) : 28.4865 , score : 18197.3097
# --> test_loss ( RMSE ) = 21.88354363837937 , score : 1700.8563
# -----> Best loss ( RMSE ) 17.128984567699252
# ------> Execution time: 0.45195484161376953 seconds
# epoch  35 :
#  --> train loss ( RMSE ) : 30.3428 , score : 24839.9642
# --> test_loss ( RMSE ) = 18.208453375983233 , score : 882.5237
# -----> Best loss ( RMSE ) 17.128984567699252
# ------> Execution time: 0.32251524925231934 seconds
# epoch  36 :
#  --> train loss ( RMSE ) : 23.2518 , score : 1718.2036
# --> test_loss ( RMSE ) = 16.233635773330708 , score : 402.5136
# -----> Best loss ( RMSE ) 16.233635773330708
# ------> Execution time: 0.32516956329345703 seconds
# epoch  37 :
#  --> train loss ( RMSE ) : 25.1012 , score : 5228.5133
# --> test_loss ( RMSE ) = 18.31108546855223 , score : 414.0899
# -----> Best loss ( RMSE ) 16.233635773330708
# ------> Execution time: 0.3291611671447754 seconds
# epoch  38 :
#  --> train loss ( RMSE ) : 28.3493 , score : 1829.4780
# --> test_loss ( RMSE ) = 16.444338462758477 , score : 371.3554
# -----> Best loss ( RMSE ) 16.233635773330708
# ------> Execution time: 0.4752521514892578 seconds
# epoch  39 :
#  --> train loss ( RMSE ) : 22.9008 , score : 666.8937
# --> test_loss ( RMSE ) = 16.890129412758608 , score : 738.9600
# -----> Best loss ( RMSE ) 16.233635773330708
# ------> Execution time: 0.3319370746612549 seconds
# epoch  40 :
#  --> train loss ( RMSE ) : 23.1529 , score : 2278.2083
# --> test_loss ( RMSE ) = 19.95323094444627 , score : 1425.1800
# -----> Best loss ( RMSE ) 16.233635773330708
# ------> Execution time: 0.3134794235229492 seconds
# epoch  41 :
#  --> train loss ( RMSE ) : 27.9517 , score : 4271.3283
# --> test_loss ( RMSE ) = 16.40586957165691 , score : 707.2210
# -----> Best loss ( RMSE ) 16.233635773330708
# ------> Execution time: 0.3112070560455322 seconds
# epoch  42 :
#  --> train loss ( RMSE ) : 25.9299 , score : 8729.9662
# --> test_loss ( RMSE ) = 16.413727555704327 , score : 364.0657
# -----> Best loss ( RMSE ) 16.233635773330708
# ------> Execution time: 0.3320639133453369 seconds
# epoch  43 :
#  --> train loss ( RMSE ) : 27.3409 , score : 1576.4787
# --> test_loss ( RMSE ) = 16.21418881748121 , score : 361.2946
# -----> Best loss ( RMSE ) 16.21418881748121
# ------> Execution time: 0.4305868148803711 seconds
# epoch  44 :
#  --> train loss ( RMSE ) : 24.4198 , score : 7139.0139
# --> test_loss ( RMSE ) = 15.142070049119326 , score : 368.7651
# -----> Best loss ( RMSE ) 15.142070049119326
# ------> Execution time: 0.3687272071838379 seconds
# epoch  45 :
#  --> train loss ( RMSE ) : 30.5788 , score : 6215.2796
# --> test_loss ( RMSE ) = 16.05574312195799 , score : 680.8432
# -----> Best loss ( RMSE ) 15.142070049119326
# ------> Execution time: 0.3298029899597168 seconds
# epoch  46 :
#  --> train loss ( RMSE ) : 21.0398 , score : 1818.5475
# --> test_loss ( RMSE ) = 19.127882477951314 , score : 1294.3132
# -----> Best loss ( RMSE ) 15.142070049119326
# ------> Execution time: 0.3127591609954834 seconds
# epoch  47 :
#  --> train loss ( RMSE ) : 29.8878 , score : 68453.2622
# --> test_loss ( RMSE ) = 19.15493788222445 , score : 1287.2548
# -----> Best loss ( RMSE ) 15.142070049119326
# ------> Execution time: 0.30796337127685547 seconds
# epoch  48 :
#  --> train loss ( RMSE ) : 24.0945 , score : 1817.3759
# --> test_loss ( RMSE ) = 14.736726185912334 , score : 459.2568
# -----> Best loss ( RMSE ) 14.736726185912334
# ------> Execution time: 0.3181023597717285 seconds
# epoch  49 :
#  --> train loss ( RMSE ) : 21.3584 , score : 952.5877
# --> test_loss ( RMSE ) = 16.204726895749907 , score : 337.9308
# -----> Best loss ( RMSE ) 14.736726185912334
# ------> Execution time: 0.29764842987060547 seconds
# epoch  50 :
#  --> train loss ( RMSE ) : 28.4552 , score : 1512.0946
# --> test_loss ( RMSE ) = 15.120493741265111 , score : 309.8103
# -----> Best loss ( RMSE ) 14.736726185912334
# ------> Execution time: 0.31023097038269043 seconds
# epoch  51 :
#  --> train loss ( RMSE ) : 20.1230 , score : 475.1806
# --> test_loss ( RMSE ) = 15.400165065410889 , score : 568.4857
# -----> Best loss ( RMSE ) 14.736726185912334
# ------> Execution time: 0.4256093502044678 seconds
# epoch  52 :
#  --> train loss ( RMSE ) : 23.4348 , score : 2034.3490
# --> test_loss ( RMSE ) = 18.134693447485475 , score : 977.9854
# -----> Best loss ( RMSE ) 14.736726185912334
# ------> Execution time: 0.36016845703125 seconds
# epoch  53 :
#  --> train loss ( RMSE ) : 29.8294 , score : 12184.3525
# --> test_loss ( RMSE ) = 18.191237920748595 , score : 983.2377
# -----> Best loss ( RMSE ) 14.736726185912334
# ------> Execution time: 0.29308652877807617 seconds
# epoch  54 :
#  --> train loss ( RMSE ) : 20.6447 , score : 648.4235
# --> test_loss ( RMSE ) = 14.61313738977688 , score : 461.5328
# -----> Best loss ( RMSE ) 14.61313738977688
# ------> Execution time: 0.35323071479797363 seconds
# epoch  55 :
#  --> train loss ( RMSE ) : 20.1195 , score : 515.9016
# --> test_loss ( RMSE ) = 14.3079464065405 , score : 420.9121
# -----> Best loss ( RMSE ) 14.3079464065405
# ------> Execution time: 0.4401817321777344 seconds
# epoch  56 :
#  --> train loss ( RMSE ) : 24.3566 , score : 2513.5503
# --> test_loss ( RMSE ) = 13.66655285577672 , score : 309.9539
# -----> Best loss ( RMSE ) 13.66655285577672
# ------> Execution time: 0.3507668972015381 seconds
# epoch  57 :
#  --> train loss ( RMSE ) : 24.5983 , score : 5313.4891
# --> test_loss ( RMSE ) = 13.597700489503744 , score : 297.6059
# -----> Best loss ( RMSE ) 13.597700489503744
# ------> Execution time: 0.3114948272705078 seconds
# epoch  58 :
#  --> train loss ( RMSE ) : 23.4796 , score : 1262.7829
# --> test_loss ( RMSE ) = 13.53830947513446 , score : 298.6049
# -----> Best loss ( RMSE ) 13.53830947513446
# ------> Execution time: 0.34494543075561523 seconds
# epoch  59 :
#  --> train loss ( RMSE ) : 23.4026 , score : 1973.6351
# --> test_loss ( RMSE ) = 13.608594000274456 , score : 325.9221
# -----> Best loss ( RMSE ) 13.53830947513446
# ------> Execution time: 0.3080861568450928 seconds
# epoch  60 :
#  --> train loss ( RMSE ) : 26.1303 , score : 2119.5619
# --> test_loss ( RMSE ) = 16.523932690142104 , score : 686.4726
# -----> Best loss ( RMSE ) 13.53830947513446
# ------> Execution time: 0.3211839199066162 seconds
# epoch  61 :
#  --> train loss ( RMSE ) : 23.1873 , score : 2686.8487
# --> test_loss ( RMSE ) = 17.372701897550133 , score : 798.9029
# -----> Best loss ( RMSE ) 13.53830947513446
# ------> Execution time: 0.32932591438293457 seconds
# epoch  62 :
#  --> train loss ( RMSE ) : 22.3015 , score : 1125.7787
# --> test_loss ( RMSE ) = 13.545201911606956 , score : 326.3977
# -----> Best loss ( RMSE ) 13.53830947513446
# ------> Execution time: 0.4241366386413574 seconds
# epoch  63 :
#  --> train loss ( RMSE ) : 22.3571 , score : 1334.1506
# --> test_loss ( RMSE ) = 15.130118378493911 , score : 276.9118
# -----> Best loss ( RMSE ) 13.53830947513446
# ------> Execution time: 0.31853652000427246 seconds
# epoch  64 :
#  --> train loss ( RMSE ) : 22.5705 , score : 1339.1400
# --> test_loss ( RMSE ) = 14.623125873749933 , score : 266.5228
# -----> Best loss ( RMSE ) 13.53830947513446
# ------> Execution time: 0.3543422222137451 seconds
# epoch  65 :
#  --> train loss ( RMSE ) : 22.0723 , score : 754.7367
# --> test_loss ( RMSE ) = 14.134216148714858 , score : 413.4793
# -----> Best loss ( RMSE ) 13.53830947513446
# ------> Execution time: 0.3352501392364502 seconds
# epoch  66 :
#  --> train loss ( RMSE ) : 20.0407 , score : 769.9896
# --> test_loss ( RMSE ) = 20.725543724812947 , score : 1472.5527
# -----> Best loss ( RMSE ) 13.53830947513446
# ------> Execution time: 0.29489946365356445 seconds
# epoch  67 :
#  --> train loss ( RMSE ) : 27.2244 , score : 2576.1358
# --> test_loss ( RMSE ) = 17.56559140982727 , score : 880.6196
# -----> Best loss ( RMSE ) 13.53830947513446
# ------> Execution time: 0.3372666835784912 seconds
# epoch  68 :
#  --> train loss ( RMSE ) : 27.3893 , score : 3197.1699
# --> test_loss ( RMSE ) = 13.210294315939155 , score : 284.9202
# -----> Best loss ( RMSE ) 13.210294315939155
# ------> Execution time: 0.43228816986083984 seconds
# epoch  69 :
#  --> train loss ( RMSE ) : 19.6336 , score : 458.7790
# --> test_loss ( RMSE ) = 14.312947046275504 , score : 263.4021
# -----> Best loss ( RMSE ) 13.210294315939155
# ------> Execution time: 0.35659146308898926 seconds
# epoch  70 :
#  --> train loss ( RMSE ) : 31.1102 , score : 3890.5012
# --> test_loss ( RMSE ) = 13.149090038916729 , score : 288.8980
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.33933472633361816 seconds
# epoch  71 :
#  --> train loss ( RMSE ) : 18.6906 , score : 441.0670
# --> test_loss ( RMSE ) = 17.00278549990938 , score : 775.7198
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.3333146572113037 seconds
# epoch  72 :
#  --> train loss ( RMSE ) : 21.1708 , score : 1338.1935
# --> test_loss ( RMSE ) = 19.135195870223267 , score : 1132.2982
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.3088538646697998 seconds
# epoch  73 :
#  --> train loss ( RMSE ) : 27.9031 , score : 8932.0209
# --> test_loss ( RMSE ) = 15.12841013336226 , score : 541.9151
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.4423832893371582 seconds
# epoch  74 :
#  --> train loss ( RMSE ) : 24.7365 , score : 4689.7691
# --> test_loss ( RMSE ) = 13.292891092500083 , score : 306.8386
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.3191664218902588 seconds
# epoch  75 :
#  --> train loss ( RMSE ) : 21.1311 , score : 1628.4076
# --> test_loss ( RMSE ) = 14.187104587393872 , score : 272.1992
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.307283878326416 seconds
# epoch  76 :
#  --> train loss ( RMSE ) : 25.0634 , score : 1047.0775
# --> test_loss ( RMSE ) = 13.740088772357975 , score : 277.0768
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.3531613349914551 seconds
# epoch  77 :
#  --> train loss ( RMSE ) : 20.4319 , score : 1525.7748
# --> test_loss ( RMSE ) = 16.3726986978288 , score : 739.2890
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.3212263584136963 seconds
# epoch  78 :
#  --> train loss ( RMSE ) : 27.2432 , score : 6490.5711
# --> test_loss ( RMSE ) = 17.064803597411743 , score : 847.9300
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.32022976875305176 seconds
# epoch  79 :
#  --> train loss ( RMSE ) : 23.6086 , score : 1459.6180
# --> test_loss ( RMSE ) = 14.343009267374836 , score : 459.7704
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.3352804183959961 seconds
# epoch  80 :
#  --> train loss ( RMSE ) : 28.2564 , score : 20429.7633
# --> test_loss ( RMSE ) = 13.68018504151528 , score : 294.8894
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.4313831329345703 seconds
# epoch  81 :
#  --> train loss ( RMSE ) : 19.4099 , score : 551.1113
# --> test_loss ( RMSE ) = 13.680294188030452 , score : 286.1364
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.30564212799072266 seconds
# epoch  82 :
#  --> train loss ( RMSE ) : 24.7267 , score : 4826.0919
# --> test_loss ( RMSE ) = 13.539557057910717 , score : 284.4106
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.331709623336792 seconds
# epoch  83 :
#  --> train loss ( RMSE ) : 25.6776 , score : 2270.9718
# --> test_loss ( RMSE ) = 14.192155050887154 , score : 421.5019
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.31267762184143066 seconds
# epoch  84 :
#  --> train loss ( RMSE ) : 24.4044 , score : 2372.2392
# --> test_loss ( RMSE ) = 14.079709042001198 , score : 400.2535
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.317516565322876 seconds
# epoch  85 :
#  --> train loss ( RMSE ) : 25.2160 , score : 4791.2084
# --> test_loss ( RMSE ) = 13.76103652227734 , score : 355.8757
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.37636780738830566 seconds
# epoch  86 :
#  --> train loss ( RMSE ) : 19.8962 , score : 1011.9336
# --> test_loss ( RMSE ) = 14.331103248487686 , score : 415.7684
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.37903833389282227 seconds
# epoch  87 :
#  --> train loss ( RMSE ) : 23.1647 , score : 3041.4815
# --> test_loss ( RMSE ) = 14.395426289241115 , score : 416.9776
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.34351181983947754 seconds
# epoch  88 :
#  --> train loss ( RMSE ) : 20.5269 , score : 1502.7364
# --> test_loss ( RMSE ) = 14.428819950387965 , score : 417.3935
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.3089442253112793 seconds
# epoch  89 :
#  --> train loss ( RMSE ) : 22.1031 , score : 14985.7647
# --> test_loss ( RMSE ) = 13.855166436704566 , score : 352.9105
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.4574766159057617 seconds
# epoch  90 :
#  --> train loss ( RMSE ) : 21.1893 , score : 1082.6709
# --> test_loss ( RMSE ) = 13.428595597189327 , score : 293.5704
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.33101987838745117 seconds
# epoch  91 :
#  --> train loss ( RMSE ) : 21.6779 , score : 1703.8873
# --> test_loss ( RMSE ) = 13.961709505565352 , score : 363.7453
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.3153872489929199 seconds
# epoch  92 :
#  --> train loss ( RMSE ) : 22.2269 , score : 3509.5751
# --> test_loss ( RMSE ) = 14.032187230716039 , score : 372.4466
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.2926011085510254 seconds
# epoch  93 :
#  --> train loss ( RMSE ) : 20.0372 , score : 1100.0946
# --> test_loss ( RMSE ) = 13.699855721987694 , score : 333.5302
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.3282768726348877 seconds
# epoch  94 :
#  --> train loss ( RMSE ) : 16.2483 , score : 388.2280
# --> test_loss ( RMSE ) = 13.87872838771991 , score : 357.3156
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.3374500274658203 seconds
# epoch  95 :
#  --> train loss ( RMSE ) : 24.1559 , score : 28986.8677
# --> test_loss ( RMSE ) = 13.949918565132045 , score : 368.4342
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.32220911979675293 seconds
# epoch  96 :
#  --> train loss ( RMSE ) : 24.6737 , score : 2967.1011
# --> test_loss ( RMSE ) = 13.640262705005407 , score : 327.5558
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.35388660430908203 seconds
# epoch  97 :
#  --> train loss ( RMSE ) : 24.5857 , score : 10268.8951
# --> test_loss ( RMSE ) = 13.699043342507602 , score : 335.3596
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.38759636878967285 seconds
# epoch  98 :
#  --> train loss ( RMSE ) : 18.5048 , score : 590.6735
# --> test_loss ( RMSE ) = 13.957686540718228 , score : 374.7116
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.39749622344970703 seconds
# epoch  99 :
#  --> train loss ( RMSE ) : 19.3088 , score : 1393.0004
# --> test_loss ( RMSE ) = 17.88153046791483 , score : 910.6440
# -----> Best loss ( RMSE ) 13.149090038916729
# ------> Execution time: 0.31725382804870605 seconds

# %% [markdown]
# # Visualize Test

# %%
def generate_prediction_with_reference(model , test_data_loader):
    max_rul = 125.0
    Yhat = []
    Y = []
    for (x,y) in test_data_loader:
        yhat = trainer.best_model(x)
        Yhat.append(yhat)
        Y.append(y)
    Yhat = torch.cat(Yhat).detach().cpu()
    Y = torch.cat(Y).detach().cpu()
    # denormalization
    Y , Yhat = Y*max_rul , Yhat*max_rul
    Y , Yhat = Y[:,0].detach().cpu().numpy() , Yhat[:,0].detach().cpu().numpy()
    return Y , Yhat

# %%
ref , prediction = generate_prediction_with_reference(trainer.best_model, test_loader)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def plot(ref , prediction, plot_pred=True, plot_ref=True):
    engine_id = np.around(np.linspace(0, 99, 100)).astype(int)
    pred_data = pd.DataFrame(data=[ref,prediction,engine_id]).T
    pred_data.columns = ["GroundTruth","Prediction","Engine_id"]
    pred_data["Prediction"] = pred_data["Prediction"].apply(lambda x : 125.0 if x > 125.0 else x)
    pred_data["GroundTruth"] = pred_data["GroundTruth"].apply(lambda x : x/10)
    pred_data["Prediction"] = pred_data["Prediction"].apply(lambda x : x/10)
    #pred_data["Engine_id"] = pred_data["Engine_id"].apply(lambda x : int(x))
    f, ax = plt.subplots(figsize=(8, 4))
    # Plot the total crashes
    if plot_pred:
        sns.set_color_codes("pastel")
        sns.barplot(x="Engine_id", y="Prediction", data=pred_data,
                    label="prediction", color="b")
    if plot_ref:
        sns.set_color_codes("muted")
        sns.barplot(x="Engine_id", y="GroundTruth", data=pred_data,
                    label="Ground Truth", color="b")

    ax.legend(ncol=2, loc="lower right", frameon=True)
    ax.set(xlim=(20, 50), ylabel="RUL",
           xlabel="Aircraft Engine ")
    sns.despine(left=False, bottom=True)

# %%
ref , prediction = generate_prediction_with_reference(trainer.best_model, test_loader)

# %%
plot(ref, prediction,plot_pred=True,plot_ref=True)

# %%
plot(ref, prediction,plot_pred=True,plot_ref=False)

# %%
def calculate_score(target, pred):
    t = torch.from_numpy(ref)
    p = torch.from_numpy(prediction)
    diff = p - t
    score = torch.sum(torch.where(diff >= 0 , torch.exp(diff/13.0) - 1 , torch.exp(-diff/10.0) - 1 )).detach().cpu().item()
    return score

# %%
calculate_score(ref,prediction)
# Out:
# 384.8313902451323

# %%
trainer.best_score
# Out:
# 14.08511269405284

# %%
today = date.today()
trainer.save_model("/kaggle/working","best_model-{}-{}-{}".format(today,trainer.best_score,"overestim_reg"))
